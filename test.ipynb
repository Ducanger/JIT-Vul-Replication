# %%
import pandas as pd
df = pd.read_pickle('data/jitline/by_time/changes_complete_buggy_line_level.pkl')
df
# Out:
#                                        commit_id  idx changed_type  label  \
# 0       00302787b788c5ff04cb6f62aed5a74d936e86c0    0        added      1
# 1       00302787b788c5ff04cb6f62aed5a74d936e86c0    1      deleted      0
# 2       00302787b788c5ff04cb6f62aed5a74d936e86c0    2      deleted      0
# 3       00302787b788c5ff04cb6f62aed5a74d936e86c0    3      deleted      0
# 4       00302787b788c5ff04cb6f62aed5a74d936e86c0    4      deleted      0
# ...                                          ...  ...          ...    ...
# 318156  fff90422d181744cd75dbf011687ee7095f02875  328        added      0
# 318157  fff90422d181744cd75dbf011687ee7095f02875  329        added      0
# 318158  fff90422d181744cd75dbf011687ee7095f02875  330        added      0
# 318159  fff90422d181744cd75dbf011687ee7095f02875  331        added      0
# 318160  fff90422d181744cd75dbf011687ee7095f02875  332        added      0
#
#                                          raw_changed_line  \
# ...

# %%
df = pd.read_pickle('C:/Users/Thinkbook/Downloads/JIT-Fine-master/data/jitline/changes_complete_buggy_line_level.pkl')
df
# Out:
#                                      commit_hash  idx changed_type  \
# 0       6e710a1f78a4a733020a4b2d1f07b6fe4c6684f0    0        added
# 1       6e710a1f78a4a733020a4b2d1f07b6fe4c6684f0    1        added
# 2       6e710a1f78a4a733020a4b2d1f07b6fe4c6684f0    2        added
# 3       6e710a1f78a4a733020a4b2d1f07b6fe4c6684f0    3        added
# 4       6e710a1f78a4a733020a4b2d1f07b6fe4c6684f0    4        added
# ...                                          ...  ...          ...
# 327567  7b80edbfe28a488e1bbbe69741ff9f8432a676b8    1        added
# 327568  7b80edbfe28a488e1bbbe69741ff9f8432a676b8    2        added
# 327569  7b80edbfe28a488e1bbbe69741ff9f8432a676b8    3      deleted
# 327570  7b80edbfe28a488e1bbbe69741ff9f8432a676b8    4      deleted
# 327571  7b80edbfe28a488e1bbbe69741ff9f8432a676b8    5      deleted
#
#         is_buggy_line                                   raw_changed_line  \
# 0                 0.0                                        throw ioe ;
# ...
